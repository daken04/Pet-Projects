# %% [markdown]
# ## Implementation of classic binary classification Perceptron

# %%
# Making dataset

import numpy as np
import pandas as pd

def generate_data():
    corr_a = 0.8
    corr_b = 0.2
    
    a = np.random.normal(0,1,size=100)
    b = np.random.normal(0,1,size=100)
    
    target = np.random.choice([0, 1], size=100)
    
    df = pd.DataFrame({'a':a, 'b':b, 'target':target})
    return df

# %%
df = generate_data()
X = df.drop('target',axis=1)
y = df['target']

print('Class label counts:', np.bincount(y))
print('X.shape:', X.shape)
print('y.shape:', y.shape)
# Out:
# Class label counts: [47 53]
# X.shape: (100, 2)
# y.shape: (100,)

# %%
X_train, X_test = X[:70], X[70:]
y_train, y_test = y[:70], y[70:]

# Normalize (mean zero, unit variance)
mu, sigma = X_train.mean(axis=0), X_train.std(axis=0)
X_train = (X_train - mu) / sigma
X_test = (X_test - mu) / sigma

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[y_train==0]['a'], X_train[y_train==0]['b'], label='class 0', marker='o')
plt.scatter(X_train[y_train==1]['a'], X_train[y_train==1]['b'], label='class 1', marker='s')
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.legend()
plt.show()
